# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "Product":["Laptop","Phone","Tablet","Laptop","Phone","Tablet","Laptop","Phone","Tablet","Laptop"],
    "Price":[50000,25000,20000,52000,27000,21000,55000,26000,22000,58000],
    "Quantity":[5,10,7,6,12,8,4,15,9,3],
    "Region":["North","South","East","West","North","South","East","West","North","South"]
}

df = pd.DataFrame(data)

df["Revenue"] = df["Price"] * df["Quantity"]

print(df)
# Out:
#   Product  Price  Quantity Region  Revenue
# 0  Laptop  50000         5  North   250000
# 1   Phone  25000        10  South   250000
# 2  Tablet  20000         7   East   140000
# 3  Laptop  52000         6   West   312000
# 4   Phone  27000        12  North   324000
# 5  Tablet  21000         8  South   168000
# 6  Laptop  55000         4   East   220000
# 7   Phone  26000        15   West   390000
# 8  Tablet  22000         9  North   198000
# 9  Laptop  58000         3  South   174000

# %%
print(df.info())
print(df.shape)
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   10 non-null     object
#  1   Price     10 non-null     int64
#  2   Quantity  10 non-null     int64
#  3   Region    10 non-null     object
#  4   Revenue   10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes
# None
# (10, 5)
#               Price   Quantity        Revenue
# count     10.000000  10.000000      10.000000
# mean   35600.000000   7.900000  242600.000000
# std    15896.889982   3.725289   79285.980266
# min    20000.000000   3.000000  140000.000000
# 25%    22750.000000   5.250000  180000.000000
# 50%    26500.000000   7.500000  235000.000000
# 75%    51500.000000   9.750000  296500.000000
# max    58000.000000  15.000000  390000.000000

# %%
print(df.isnull().sum())
# Out:
# Product     0
# Price       0
# Quantity    0
# Region      0
# Revenue     0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print("Total Revenue =", df["Revenue"].sum())
# Out:
# Total Revenue = 2426000

# %%
product_revenue = df.groupby("Product")["Revenue"].sum()

print(product_revenue)

product_revenue.plot(kind="bar")
plt.title("Revenue by Product")
plt.ylabel("Revenue")
plt.show()
# Out:
# Product
# Laptop    956000
# Phone     964000
# Tablet    506000
# Name: Revenue, dtype: int64

# %%
region_revenue = df.groupby("Region")["Revenue"].sum()

print(region_revenue)

region_revenue.plot(kind="bar")
plt.title("Revenue by Region")
plt.ylabel("Revenue")
plt.show()
# Out:
# Region
# East     360000
# North    772000
# South    592000
# West     702000
# Name: Revenue, dtype: int64

# %%
plt.hist(df["Quantity"])
plt.title("Quantity Distribution")
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["Price"], df["Revenue"])
plt.xlabel("Price")
plt.ylabel("Revenue")
plt.title("Price vs Revenue")
plt.show()

# %%
best_product = df.groupby("Product")["Quantity"].sum()

print(best_product)

print("Best Selling Product:")
print(best_product.idxmax())
# Out:
# Product
# Laptop    18
# Phone     37
# Tablet    24
# Name: Quantity, dtype: int64
# Best Selling Product:
# Phone

# %%
highest_region = df.groupby("Region")["Revenue"].sum()

print("Highest Revenue Region:")
print(highest_region.idxmax())
# Out:
# Highest Revenue Region:
# North

# %%
print("KEY FINDINGS")

print("1. No missing values found.")
print("2. No duplicate records found.")
print("3. Phones generated the highest sales volume.")
print("4. Revenue varies across regions.")
print("5. Product price impacts revenue generation.")
print("6. Retail data shows strong business trends.")
# Out:
# KEY FINDINGS
# 1. No missing values found.
# 2. No duplicate records found.
# 3. Phones generated the highest sales volume.
# 4. Revenue varies across regions.
# 5. Product price impacts revenue generation.
# 6. Retail data shows strong business trends.
